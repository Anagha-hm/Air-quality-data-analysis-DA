# %%
import pandas as pd
import numpy as np
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('city_day.csv')
df2 = pd.read_csv('city_hour.csv')
df3 = pd.read_csv('station_day.csv')
df4 = pd.read_csv('station_hour.csv')
df5 = pd.read_csv('stations.csv')

# %%
df1.dtypes
# Out:
# City           object
# Date           object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
# dtype: object

# %%
df1.shape
# Out:
# (29531, 16)

# %%
df1.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
df1.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %% [markdown]
# When speaking of air pollution- benzene, toluene and xylene are not gases that come up often. One can assume their contribution to air pollution is insignificant. Our assumptions are given validation by the description of the above database.

# %%
city_day = df1.copy()
city_day['BTX'] = city_day['Benzene']+city_day['Toluene']+city_day['Xylene']
city_day['Particulate_Matter'] = city_day['PM2.5']+city_day['PM10']
city_day['Nitrogen Oxides'] = city_day['NO']+city_day['NO2']+city_day['NOx']
city_day.drop(['Benzene','Toluene','Xylene','PM2.5','PM10','NO','NO2','NOx'],axis=1,inplace=True)

plt.figure(figsize=(9,9))
sns.heatmap(city_day.corr(),cmap='coolwarm',annot=True);

# %%
df1[df1.isna().any(axis=1)]
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx   NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15   NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46   NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70   NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97   NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76   NaN
# ...              ...         ...    ...    ...    ...    ...    ...   ...
# 29433  Visakhapatnam  2020-03-26  21.29  57.46   6.26  25.26  18.53   NaN
# 29462  Visakhapatnam  2020-04-24    NaN    NaN    NaN    NaN    NaN   NaN
# 29463  Visakhapatnam  2020-04-25    NaN    NaN    NaN    NaN    NaN   NaN
# 29464  Visakhapatnam  2020-04-26  11.07  31.30   4.65  19.97  13.07  7.88
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05  5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# ...

# %%
##To fill nan values - weekly avg
##values from hourly df

# %%
df2.head(10)
# Out:
#         City             Datetime  PM2.5  PM10    NO    NO2    NOx  NH3    CO  \
# 0  Ahmedabad  2015-01-01 01:00:00    NaN   NaN  1.00  40.01  36.37  NaN  1.00
# 1  Ahmedabad  2015-01-01 02:00:00    NaN   NaN  0.02  27.75  19.73  NaN  0.02
# 2  Ahmedabad  2015-01-01 03:00:00    NaN   NaN  0.08  19.32  11.08  NaN  0.08
# 3  Ahmedabad  2015-01-01 04:00:00    NaN   NaN  0.30  16.45   9.20  NaN  0.30
# 4  Ahmedabad  2015-01-01 05:00:00    NaN   NaN  0.12  14.90   7.85  NaN  0.12
# 5  Ahmedabad  2015-01-01 06:00:00    NaN   NaN  0.33  15.95  10.82  NaN  0.33
# 6  Ahmedabad  2015-01-01 07:00:00    NaN   NaN  0.45  15.94  12.47  NaN  0.45
# 7  Ahmedabad  2015-01-01 08:00:00    NaN   NaN  1.03  16.66  16.48  NaN  1.03
# 8  Ahmedabad  2015-01-01 09:00:00    NaN   NaN  1.47  16.25  18.02  NaN  1.47
# 9  Ahmedabad  2015-01-01 10:00:00    NaN   NaN  2.05  13.78  16.08  NaN  2.05
#
#       SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# ...

# %%
df2.shape
# Out:
# (707875, 16)

# %%
##if pm and aqi are missing, drop rows

# %%
df3.head(10)
# Out:
#   StationId        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 0     AP001  2017-11-24  71.36  115.75  1.75  20.65  12.40  12.19  0.10
# 1     AP001  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2     AP001  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 3     AP001  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 4     AP001  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42  0.09
# 5     AP001  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25  0.16
# 6     AP001  2017-11-30  69.80  114.86  4.69  20.17  14.54  10.95  0.12
# 7     AP001  2017-12-01  73.96  113.56  4.58  19.29  13.97  10.95  0.10
# 8     AP001  2017-12-02  89.90  140.20  7.71  26.19  19.87  13.12  0.10
# 9     AP001  2017-12-03  87.14  130.52  0.97  21.31  12.12  14.36  0.15
#
#      SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 0  10.76  109.26     0.17     5.92    0.10    NaN        NaN
# ...

# %%
df4.head(10)
# Out:
#   StationId             Datetime  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 0     AP001  2017-11-24 17:00:00  60.50   98.00  2.35  30.80  18.25   8.50
# 1     AP001  2017-11-24 18:00:00  65.50  111.25  2.70  24.20  15.07   9.77
# 2     AP001  2017-11-24 19:00:00  80.00  132.00  2.10  25.18  15.15  12.02
# 3     AP001  2017-11-24 20:00:00  81.50  133.25  1.95  16.25  10.23  11.58
# 4     AP001  2017-11-24 21:00:00  75.25  116.00  1.43  17.48  10.43  12.03
# 5     AP001  2017-11-24 22:00:00  69.25  108.25  0.70  18.47  10.38  13.80
# 6     AP001  2017-11-24 23:00:00  67.50  111.50  1.05  12.15   7.30  17.65
# 7     AP001  2017-11-25 00:00:00  68.00  111.00  1.25  14.12   8.50  20.28
# 8     AP001  2017-11-25 01:00:00  73.00  102.00  0.30  14.30   7.90  11.50
# 9     AP001  2017-11-25 02:00:00  81.00  123.00  0.80  24.85  13.88  10.28
#
#     CO    SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  0.1  11.85  126.40     0.10     6.10    0.10  NaN        NaN
# ...

# %%
df5.head(10)
# Out:
#   StationId                                     StationName  \
# 0     AP001                  Secretariat, Amaravati - APPCB
# 1     AP002  Anand Kala Kshetram, Rajamahendravaram - APPCB
# 2     AP003                      Tirumala, Tirupati - APPCB
# 3     AP004                 PWD Grounds, Vijayawada - APPCB
# 4     AP005          GVM Corporation, Visakhapatnam - APPCB
# 5     AS001                 Railway Colony, Guwahati - APCB
# 6     BR001                      Collectorate, Gaya - BSPCB
# 7     BR002                     SFTI Kusdihra, Gaya - BSPCB
# 8     BR003                Industrial Area, Hajipur - BSPCB
# 9     BR004   Muzaffarpur Collectorate, Muzaffarpur - BSPCB
#
#                 City           State  Status
# 0          Amaravati  Andhra Pradesh  Active
# 1  Rajamahendravaram  Andhra Pradesh     NaN
# 2           Tirupati  Andhra Pradesh     NaN
# 3         Vijayawada  Andhra Pradesh     NaN
# 4      Visakhapatnam  Andhra Pradesh  Active
# ...
